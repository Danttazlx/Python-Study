# %%
# declarando uma lista 

list = ["Daniel Dantas","Leonardo","Eloah "
        ,"Joaquim Dantas","Maria Das Graça","Valeria","Zé"] 

for i in list:
    if i == "Leonardo": 
        continue
    print(i)
# Out:
# Daniel Dantas
# Eloah
# Joaquim Dantas
# Maria Das Graça
# Valeria
# Zé
