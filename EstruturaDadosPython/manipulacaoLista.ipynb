# %%
list = ['Dantas', 20, 'FC: Ciência de Dados','Negro']

# len() -> ele conta a quantidade de elementos detro de uma lista

len(list)
# Out:
# 4

# %%
# particao por index

# primeiro idex até o 5 -1
list[1:5]
# segundo index pra frente
list[:2]
# do primeiro index até o final
list[0:]
# : tudo
list[:]
# Out:
# ['Dantas', 20, 'FC: Ciência de Dados', 'Negro']

# %%
# metodo adicionar

list.append("sla")
list
# Out:
# ['Dantas', 20, 'FC: Ciência de Dados', 'Negro', 'sla']

# %%
# metodo remover

list.remove('sla')
list
# Out:
# ['Dantas', 20, 'FC: Ciência de Dados', 'Negro']

# %%
# metodo limpar

list.clear()
list
# Out:
# []

# %%
# metodo extend

list.extend(['Dantas', 20, 'FC: Ciência de Dados', 'Negro'])
list
# Out:
# ['Dantas', 20, 'FC: Ciência de Dados', 'Negro']

# %%
# metodo insert 

list.insert(0,"Daniel")
list
# Out:
# ['Daniel', 'Dantas', 20, 'FC: Ciência de Dados', 'Negro']

# %%
# metodo pop

list.pop(4)
# Out:
# 'Negro'

# %%
list
# Out:
# ['Daniel', 'Dantas', 20, 'FC: Ciência de Dados']

# %%
list.extend(["a","b","c","d","e","f","g","h","i","j","k","l","m"])
list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
# metodo sort 

list.sort()
list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']
