# %%
"""
A quantidade total de empregados;
A diferença entre o salário mais baixo e mais alto;
A média ponderada da faixa salarial da escola.
"""

q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500


total_empregadores = q_seguranca + q_docente + q_diretoria
total_empregadores
# Out:
# 9500

# %%
diferenca = s_diretoria - s_seguranca
diferenca
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 diferenca = s_diretoria - s_seguranca
#       2 diferenca
#
# NameError: name 's_diretoria' is not defined
