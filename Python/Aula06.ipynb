# %%
s1 = 'Olá, mundo!'
s2 = "Olá, mundo!"
print(type(s1), type(s2))

# %%
texto = '  Daniel Danyas '
texto

# %%
text = texto.replace('y', 't').strip().upper()
text
# Out:
# 'DANIEL DANTAS'

# %%
# metodos, upper Maiusculo, 
# strip apagar espacos no comco e no final,
# reaplace mudar uma letra ou caracter especifico 

texto.upper()
texto.strip()
texto.replace('y', 't')
