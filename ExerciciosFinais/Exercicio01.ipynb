# %%
listPreco = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]

somaPreco = sum(listPreco)
tamanho = len(listPreco)

print(f'Média de gasto: {(somaPreco / tamanho)}')
# Out:
# Média de gasto: 3144.222
