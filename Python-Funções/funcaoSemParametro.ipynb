# %%
# funcao sem parametro

def printar ():
    print('vizao')

printar()
# Out:
# vizao

# %%
def conta ():
   continha = (7+3+5-3)/2
   print(continha)

conta()
# Out:
# 6.0

# %%
# função com parametro

def calcular_nota (nota1, nota2, nota3):
    somaNota = (nota1 + nota2 + nota3)
    print(somaNota)


calcular_nota(3,5,7)
# Out:
# 15

# %%
# atribuindo valores dentro dos parametros

carro1 = 'mercedes'
carro2 = 'ferrari'
carro3 = 'Red bull'


F1 = {'Mercedes', 'Red bull', 'ferrari'}



def corrida (carro_1 = carro1, carro_2 = carro2, carro_3 = carro3):
        print(carro_1,carro_2,carro_3)

corrida()
# Out:
# mercedes ferrari Red bull
# NoneType

# %%
resultado = corrida()
# Out:
# mercedes ferrari Red bull

# %%
resultado

# %%
type(resultado)
# Out:
# NoneType

# %%
# funcao com retorno

nome = ['Dantas','Daniel']


def funcaoDeRetorno (lista):
   return lista


funcaoDeRetorno(nome)
# Out:
# ['Dantas', 'Daniel']

# %%
# função lambda + map

notas = [5,5.5,8.5,9.5]
qualitativo = 0.5


 
valorAtualizado = list(map(lambda x : x + qualitativo, notas))
valorAtualizado
# Out:
# [5.5, 6.0, 9.0, 10.0]
