# %%
entrada = int(input('qual taboada voce quer ? (0-10) '))

for taboada in range(11):
    calculo =  entrada * taboada
    print(f'{entrada} x {taboada} = {calculo}')
# Out:
# 100 x 0 = 0
# 100 x 1 = 100
# 100 x 2 = 200
# 100 x 3 = 300
# 100 x 4 = 400
# 100 x 5 = 500
# 100 x 6 = 600
# 100 x 7 = 700
# 100 x 8 = 800
# 100 x 9 = 900
# 100 x 10 = 1000
