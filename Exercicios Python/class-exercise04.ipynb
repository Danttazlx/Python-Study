# %%
nome_aluno = 'fabricio Daniel'
idade_aluno = 16
sitacao_aprovado = True
print('o aluno {nome_aluno} tem {idade_aluno} anos e esta aprovado!! {sitacao_aprovado}'
      .format(nome_aluno=nome_aluno, idade_aluno=idade_aluno, sitacao_aprovado=sitacao_aprovado))
# Out:
# o aluno fabricio Daniel tem 16 anos e esta aprovado? True
